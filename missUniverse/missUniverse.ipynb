# %%
import pandas as pd

# %%
pd.read_excel("missUniWor.xlsx")
# Out:
#     Year         Country        Titleholder   Age        Hometown  \
# 0   1951             NaN                NaN   NaN             NaN
# 1   1952         Finland       Armi Kuusela  17.0           Muhos
# 2   1953          France  Christiane Martel  17.0         Créteil
# 3   1954   United States   Miriam Stevenson  21.0       Winnsboro
# 4   1955          Sweden     Hillevi Rombin  21.0           Alfta
# ..   ...             ...                ...   ...             ...
# 67  2017    South Africa         Demi-Leigh  22.0      Sedgefield
# 68  2018     Philippines      Catriona Gray  24.0             Oas
# 69  2019    South Africa     Zozibini Tunzi  26.0           Tsolo
# 70  2020          Mexico        Andrea Meza  26.0  Chihuahua City
# 71  2021           India     Harnaaz Sandhu  21.0      Chandigarh
#
#                     National Title               Date  Entrants
# 0                              NaN                NaN       NaN
# ...
